# %%
## minimisation experiments

from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components=100, n_iter=7, random_state=42)
svd.fit(XAmean)

XAmean_new = svd.inverse_transform( svd.transform(XAmean) )

np.std( XAmean_new-XAmean)

plt.plot(svd.components_[40])

U,W,VT = svd(XAmean)

from sklearn.svm.

from sklearn.svm



f = plt.figure(figsize=[20,10])
plt.subplot(1,2,1)
plt.imshow(XAmean)

plt.subplot(1,2,2)
plt.imshow(VT, interpolation='nearest')


plt.plot(np.log(W[:300]))

import scipy as sc
from scipy import stats

stats.entropy([1.-0.000000001,0.000000001]) 


XAmean.shape
XAmean[:2, 500:505].shape
pcaA.components_[0][500:503]

import scipy.optimize as opt


# Convert to minimization problem by negating function
def f(x):
    #print(x)
    return -sc.stats.entropy(x)

N = 15

V = np.array(pcaA.components_[0][490:503])

M = XAmean.T[490:503,:N]

cons = ({'type': 'eq',
         'fun' : lambda x: np.matmul(M, x) - V })

x0 = np.ones(N)/N
cx = opt.minimize(f, x0, constraints=cons)
cx

a = np.array([[3,1], [1,2]])
b = np.array([9,8])
x = np.linalg.solve(a, b)

a

M.shape

x = [1,2,3]
f = lambda x: np.array([x[0] + 2*x[1] - 6, x[0] - 3*x[2]])
f(x)

print(np.matmul(M, cx.x))
print(V)

N = XAmean.shape[0]
x0 = np.ones(N) / N
np.matmul(XAmean.T, x0).shape


XAmean = np.array([[1,0,0],[1,0,0],[0,1,0]])

# Convert to minimization problem by negating function

n_components 

def f(x):
    return sc.stats.entropy(x)

cons = ({'type': 'eq',
         'fun' : lambda x: np.matmul(XAmean.T, x).shape - pcaA.components_[0] })

N = XAmean.shape[0]
x0 = np.ones(N) / N
cx = opt.minimize(f, x0, constraints=cons)



import numpy as np

x = np.linspace(-1.5, 1.5)

[X, Y] = np.meshgrid(x, x)

import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot_surface(X, Y, X + Y)

theta = np.linspace(0,2*np.pi);
R = 1.0
x1 = R * np.cos(theta)
y1 = R * np.sin(theta)

ax.plot(x1, y1, x1 + y1, 'r-')
#plt.savefig('images/lagrange-1.png')


def func(X):
    x = X[0]
    y = X[1]
    L = X[2] # the multiplier
    return x + y + L *(x**2 + y**2 -1)


def dfunc(X):
    dLambda = np.zeros(len(X))
    h = 1e-3 # step size used in the finite differences
    for i in range(len(X)):
        dX = np.zeros(len(X))
        dX[i] = h
        dLambda[i] = (func(X + dX) - func(X - dX))/(2*h)
    return dLambda


from scipy.optimize import fsolve

# the max
X1 = fsolve(dfunc, [1, 1, 0])
print(X1, func(X1))

# the min
X2 = fsolve(dfunc, [-1, -1, 0])
print(X2, func(X2))


fig5 = plt.figure()
ax5 = Axes3D(fig5)
ax5.plot_surface(X, Y, X+Y, color='y', rstride=100, cstride=100, alpha=0.2, edgecolor='w')
ax5.plot_surface(X, Y, np.zeros_like(X), color='b', alpha=0.05, rstride=100, cstride=100)

theta = np.linspace(0, 2*np.pi)
R = 1.0
x1 = R * np.cos(theta)
y1 = R * np.sin(theta)
ax5.plot(x1, y1, alpha=0.3)
ax5.plot(x1, y1, x1+y1, c='y', alpha=0.8)

ax5.scatter(X1[0], X1[1], X1[2], s=30, c='r')
ax5.scatter(X2[0], X2[1], X2[2], s=30, c='g')

### End minimisation experiments
